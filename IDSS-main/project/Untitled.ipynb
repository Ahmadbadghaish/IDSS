# %%
#1. Reading & displaying the data 
import pandas as pd
df = pd.read_csv('data.csv', delimiter = ',')
display(df)
# Out:
#       0  neuroticism_scores  extroversion_scores  openness_scores  \
# 0     1               20.84                51.96            45.72
# 1     2               22.39                54.07            55.71
# 2     3               23.75                57.80            42.42
# 3     4                9.70                45.27            44.58
# 4     5               11.85                44.53            46.97
# ..  ...                 ...                  ...              ...
# 95   96               13.79                41.46            38.77
# 96   97               24.53                55.03            45.86
# 97   98               31.30                56.55            49.66
# 98   99               20.70                39.71            38.69
# 99  100               21.30                52.02            50.26
#
#     agreeableness_scores  conscientiousness_scores
# 0                  45.53                     34.60
# 1                  41.56                     44.16
# ...

# %%
display(df.head(5))
display(df.info())
# Out:
#    0  neuroticism_scores  extroversion_scores  openness_scores  \
# 0  1               20.84                51.96            45.72
# 1  2               22.39                54.07            55.71
# 2  3               23.75                57.80            42.42
# 3  4                9.70                45.27            44.58
# 4  5               11.85                44.53            46.97
#
#    agreeableness_scores  conscientiousness_scores
# 0                 45.53                     34.60
# 1                 41.56                     44.16
# 2                 65.82                     49.34
# 3                 58.71                     40.88
# 4                 40.71                     47.39
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   0                         100 non-null    int64
# ...

# %%
#     5.iii. Box-Plots for each numerical and categorical column (skip *subscribed* column), 
# and differentiate using *subscribed* column.
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28928/280608955.py in <module>
#       9
#      10
# ---> 11 fig,ax = plt.subplots(len(cat_columns), len(num_columns), figsize=(25,25))
#      12
#      13 for c,nCol in enumerate(num_columns):
#
# ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1438     """
#    1439     fig = figure(**fig_kw)
# ...
